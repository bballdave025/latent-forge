# %% [markdown]
# # Latent Forge — recommender experiments
#
# Start with the course baseline, then make one assumption-changing experiment at a time. **Validation MSE decides.**

# %% [markdown]
# ## Dave Rule
# 1. What assumption changes?
# 2. Why should it improve?
# 3. How will success be measured?
# 4. Is the added complexity justified?

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from latent_forge.baselines import item_mean_fit, item_mean_predict

# %% [markdown]
# ## 0. Reproduce the rank-1 / item-mean baseline
# Paste/adapt the course data-loading code here first. Keep this result as the anchor for every later experiment.

# %% [markdown]
# ## Experiment 1
# **Assumption change:** _fill in before coding_
# **Why it might improve holdout MSE:** _fill in_
# **Success criterion:** validation MSE lower than the current best
# **Complexity justified?** _fill in_

# %% [markdown]
# ## Captured branches
# Heavier ideas live in `docs/branches.md`. They are hooks, not today's scope.
